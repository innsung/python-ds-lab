# %% [markdown]
# # 화면 출력
#
# - print() 함수를 이용하여 화면 출력
# - 기본 출력 : 출력 형식 지정하지 않고 데이터를 출력하는 방법
# - 형식(attribute) 지정 : sep, end .. 속성을 적용하여 다양하게 출력하는 방법

# %%
print('Hello~ python!!')
# Out:
# Hello~ python!!

# %%
# 이름은 홍길동이고 나이는 30살 입니다.
name = '홍길동'
age = 30 
print(f"이름은'{name}'이고  나이는 {age}살 입니다.")
# Out:
# 이름은'홍길동'이고  나이는 30살 입니다.

# %% [markdown]
# # 키보드 입력

# %% [markdown]
# - 키보드로 데이터를 입력받기 위해서는 input() 함수 사용
# - 형식 : 변수 = input('문자열')
# - input()함수를 통해 입력받은 값은 기본 문자열로 인식

# %%
name = input('이름:')
age = input('나이:')
print(f"이름은 {name} 이고, 나이는{age}살 입니다")
# Out:
# 이름: 홍길동
# 나이: 30
# 이름은 홍길동 이고, 나이는30살 입니다

# %%
# 구구단을 입력받아 실행
dan = input('단 입력: ')
for n in range(1, 10):
    print(f"{dan} x {n} = {int(dan)*n}")
# Out:
# 단 입력:  3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27

# %%
# 구구단 실행 - 시작, 종료 단을 입력 받기
start = input('시작:')
end = input('종료:')
for n in range(1, 10): # 행
    for dan in range(int(start), int(end)+1): # 컬럼
        print(f"{dan} x {n} = {dan*n}", end="\t")
    print()
# Out:
# 시작: 2
# 종료: 7
# 2 x 1 = 2	3 x 1 = 3	4 x 1 = 4	5 x 1 = 5	6 x 1 = 6	7 x 1 = 7
# 2 x 2 = 4	3 x 2 = 6	4 x 2 = 8	5 x 2 = 10	6 x 2 = 12	7 x 2 = 14
# 2 x 3 = 6	3 x 3 = 9	4 x 3 = 12	5 x 3 = 15	6 x 3 = 18	7 x 3 = 21
# 2 x 4 = 8	3 x 4 = 12	4 x 4 = 16	5 x 4 = 20	6 x 4 = 24	7 x 4 = 28
# 2 x 5 = 10	3 x 5 = 15	4 x 5 = 20	5 x 5 = 25	6 x 5 = 30	7 x 5 = 35
# 2 x 6 = 12	3 x 6 = 18	4 x 6 = 24	5 x 6 = 30	6 x 6 = 36	7 x 6 = 42
# 2 x 7 = 14	3 x 7 = 21	4 x 7 = 28	5 x 7 = 35	6 x 7 = 42	7 x 7 = 49
# 2 x 8 = 16	3 x 8 = 24	4 x 8 = 32	5 x 8 = 40	6 x 8 = 48	7 x 8 = 56
# 2 x 9 = 18	3 x 9 = 27	4 x 9 = 36	5 x 9 = 45	6 x 9 = 54	7 x 9 = 63
