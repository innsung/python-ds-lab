# %% [markdown]
# #### 앙상블(Ensemble)
# - 여러개의 분류모델을 조합해서 더 나은 성능을 내는 방법
# - Decision Tree 모델을 증가시켜 나온 랜덤포레스트가 대표적임

# %% [markdown]
# ##### 랜덤포레스트(Random Forest)
# ###### 랜덤포레스트 훈련방법
# - 부트스트램 샘플 : 중복을 허용하는 샘플링 방법
# - 샘플링 후에 샘플을 복구하고 다시 샘플링 하는 방법입니다.
# - 이와 같이 진행하는 이유는 결정트리에서 과대적합을 방지할 수 있기 때문이다.
# - 각 결정트리에서 나오는 확률의 합을 트리갯수로 나누어서 결정짓는 모델
# - 부트스트랩의 샘플링 갯수 : 특성의 갯수의 제곱근

# %%
import pandas as pd

# %%
wine = pd.read_csv("../Data/wine.csv")

# %%
# Feature와 Target
data = wine[['alcohol', 'sugar', 'pH']].to_numpy()
target = wine['class'].to_numpy()

# %%
from sklearn.model_selection import train_test_split

# %%
train_input, test_input, train_target, test_target = \
    train_test_split(
        data,
        target,
        test_size=0.2,
        random_state=42,
        stratify=target
    )

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_validate

# %%
rf = RandomForestClassifier(
    n_jobs = -1 # 내 PC의 모든 가용한 자원 사용
)
scores = cross_validate(
    rf,
    train_input,
    train_target,
    return_train_score=True,
    n_jobs=-1
)
scores
# Out:
# {'fit_time': array([0.25041056, 0.23513293, 0.24467754, 0.22913361, 0.23335624]),
#  'score_time': array([0.02878499, 0.02733254, 0.02558351, 0.0292201 , 0.02862406]),
#  'test_score': array([0.90192308, 0.9       , 0.88450433, 0.88835419, 0.8825794 ]),
#  'train_score': array([0.99807554, 0.99807554, 0.9983165 , 0.998076  , 0.9983165 ])}

# %%
print("Train : ", scores['train_score'].mean())
print("Test : ", scores['test_score'].mean())
# Out:
# Train :  0.9981720130385032
# Test :  0.8914721996002072

# %%
rf.fit(train_input, train_target)
rf.score(test_input,test_target)
# Out:
# 0.8907692307692308

# %%
# 중요 Feature
print(rf.feature_importances_)
# Out:
# [0.229524   0.49782522 0.27265077]

# %% [markdown]
# ----
# #### Extra Tree
# - 기본적으로 100개의 트리를 사용
# - 노드 분할시 특성의 제곱근의 갯수를 사용
# - 특성의 선택을 랜덤하게 선택한다.
# - 특성의 선택을 랜덤하게 하므로 속도는 랜덤포레스트 보다 빠르다.

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
et = ExtraTreesClassifier(n_jobs=-1)
scores = cross_validate(
    et,
    train_input,
    train_target,
    return_train_score=True,
    n_jobs=-1
)
print("Train : ", scores['train_score'].mean())
print("Test : ", scores['test_score'].mean())
# Out:
# Train :  0.9981720130385032
# Test :  0.8912787813726217

# %% [markdown]
# ----
# #### Gradient Boosting
# - 가장 유명한 알고리즘중 하나이다.
# - 경사하강법 처럼 손실함수를 사용한다.
# - 손실함수를 보고 트리를 추가하여 최적의 값 도출하는 방법이다.
# - max depth는 3으로 제어됨 -> 과대적합 방지
# - 단점은 손실함수를 확인하고 트리는 추가하는 모델이므로 n_jobs(병렬처리)를 할 수 없다.

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb = GradientBoostingClassifier()

scores = cross_validate(
    gb,
    train_input,
    train_target,
    return_train_score=True,
    n_jobs=-1
)
print("Train : ", scores['train_score'].mean())
print("Test : ", scores['test_score'].mean())
# Out:
# Train :  0.886136193834053
# Test :  0.8714622047827053

# %% [markdown]
# ----
# #### Histogram Gradient Boosting
# - 훈련데이터를 256개의 구간으로 나누어서 훈련시키는 방법
# - 특성의 범위가 제한되어 있어 빠른 속도를 제공한다.
# - 제한된 구간이므로 과대적합을 방지한다.

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
hgb = HistGradientBoostingClassifier()

scores = cross_validate(
    hgb,
    train_input,
    train_target,
    return_train_score=True,
    n_jobs=-1
)
print("Train : ", scores['train_score'].mean())
print("Test : ", scores['test_score'].mean())
# Out:
# Train :  0.930536541746549
# Test :  0.8780021470348707

# %% [markdown]
# ----
# #### LightGBM
# - Gradient Boosting 에서 출발

# %%
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\tjoeun\anaconda3\lib\site-packages (from lightgbm) (2.3.5)
# Requirement already satisfied: scipy in c:\users\tjoeun\anaconda3\lib\site-packages (from lightgbm) (1.16.3)
# Downloading lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 37.9 MB/s  0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0

# %%
from lightgbm import LGBMClassifier

# %%
lgb = LGBMClassifier()

scores = cross_validate(
    lgb,
    train_input,
    train_target,
    return_train_score=True,
    n_jobs=-1
)
print("Train : ", scores['train_score'].mean())
print("Test : ", scores['test_score'].mean())
# Out:
# Train :  0.934577605325741
# Test :  0.8805047382838529
