# %% [markdown]
# # 지도 시각화

# %%
#!pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\tjoeun\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (2.3.5)
# Requirement already satisfied: requests in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\tjoeun\anaconda3\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tjoeun\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tjoeun\anaconda3\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tjoeun\anaconda3\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tjoeun\anaconda3\lib\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tjoeun\anaconda3\lib\site-packages (from requests->folium) (2025.11.12)

# %% [markdown]
# ### 기본 지도 그리기

# %%
import folium

m = folium.Map(
    location=[37.566826, 126.9786567],
    zoom_start=11
)

m.save('data/map_basic.html')
print('지도 저장 완료: data/map_basic.html')
m
# Out:
# 지도 저장 완료: data/map_basic.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be2eaf8b77b19755196eb06683d38ab0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be2eaf8b77b19755196eb06683d38ab0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be2eaf8b77b19755196eb06683d38ab0 = L.map(
#                 &quot;map_be2eaf8b77b19755196eb06683d38ab0&quot;,
#                 {
#                     center: [37.566826, 126.9786567],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f10018a8661596dccd20b4ea65e643f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9f10018a8661596dccd20b4ea65e643f.addTo(map_be2eaf8b77b19755196eb06683d38ab0);
#
#
#             tile_layer_9f10018a8661596dccd20b4ea65e643f.addTo(map_be2eaf8b77b19755196eb06683d38ab0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 마커 + 팝업 + 툴팁

# %%
locations = [
    {'name': '경복궁', 'lat': 37.5796, 'lon': 126.9770, 'desc': '조선의 법궁'},
    {'name': '남산타워', 'lat': 37.5512, 'lon': 126.9882, 'desc': 'N서울타워'},
    {'name': '인사동', 'lat': 37.5741, 'lon': 126.9862, 'desc': '전통문화거리'},
]

m2 = folium.Map(location=[37.566, 126.977], zoom_start=13)

for loc in locations:
    folium.Marker(
        location=[loc['lat'], loc['lon']],
        popup=folium.Popup(f"<b>{loc['name']}</b><br>{loc['desc']}", max_width=200),
        tooltip=loc['name'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m2)

m2.save('data/map_markers.html')
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f6fed22a33281c8aba766e512cc388e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f6fed22a33281c8aba766e512cc388e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f6fed22a33281c8aba766e512cc388e = L.map(
#                 &quot;map_8f6fed22a33281c8aba766e512cc388e&quot;,
#                 {
#                     center: [37.566, 126.977],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_314bc3c9843190dcaa7a02c84412699b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_314bc3c9843190dcaa7a02c84412699b.addTo(map_8f6fed22a33281c8aba766e512cc388e);
#
#
#             var marker_5351e72906928613e2b8d004989805f0 = L.marker(
#                 [37.5796, 126.977],
#                 {
# }
#             ).addTo(map_8f6fed22a33281c8aba766e512cc388e);
#
#
#             var icon_2d5ad5562869d781f779334febabb041 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_364a333cac9db29cf20a4a8f041e2952 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_554ad425a43cf9621063a3ca8092920d = $(`&lt;div id=&quot;html_554ad425a43cf9621063a3ca8092920d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;경복궁&lt;/b&gt;&lt;br&gt;조선의 법궁&lt;/div&gt;`)[0];
#                 popup_364a333cac9db29cf20a4a8f041e2952.setContent(html_554ad425a43cf9621063a3ca8092920d);
#
#
#
#         marker_5351e72906928613e2b8d004989805f0.bindPopup(popup_364a333cac9db29cf20a4a8f041e2952)
#         ;
#
#
#
#
#             marker_5351e72906928613e2b8d004989805f0.bindTooltip(
#                 `&lt;div&gt;
#                      경복궁
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_5351e72906928613e2b8d004989805f0.setIcon(icon_2d5ad5562869d781f779334febabb041);
#
#
#             var marker_215607dc54978a43c781af7dce2b9fbe = L.marker(
#                 [37.5512, 126.9882],
#                 {
# }
#             ).addTo(map_8f6fed22a33281c8aba766e512cc388e);
#
#
#             var icon_d52279cec7a082cd5151b295af7d081d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0f5cfee5eccdfdc753aff9c833c9d8cd = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_4db8bfab1522b8a7d8cb22ca3774fe8f = $(`&lt;div id=&quot;html_4db8bfab1522b8a7d8cb22ca3774fe8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;남산타워&lt;/b&gt;&lt;br&gt;N서울타워&lt;/div&gt;`)[0];
#                 popup_0f5cfee5eccdfdc753aff9c833c9d8cd.setContent(html_4db8bfab1522b8a7d8cb22ca3774fe8f);
#
#
#
#         marker_215607dc54978a43c781af7dce2b9fbe.bindPopup(popup_0f5cfee5eccdfdc753aff9c833c9d8cd)
#         ;
#
#
#
#
#             marker_215607dc54978a43c781af7dce2b9fbe.bindTooltip(
#                 `&lt;div&gt;
#                      남산타워
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_215607dc54978a43c781af7dce2b9fbe.setIcon(icon_d52279cec7a082cd5151b295af7d081d);
#
#
#             var marker_4c87a577d26349a4fa3c6f7674bc0bca = L.marker(
#                 [37.5741, 126.9862],
#                 {
# }
#             ).addTo(map_8f6fed22a33281c8aba766e512cc388e);
#
#
#             var icon_1076e73e199b76e7382044c8c1efbdc1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c9cc4ce097187370604b32383444a780 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_1152569b14c759d290efe0d549747269 = $(`&lt;div id=&quot;html_1152569b14c759d290efe0d549747269&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&l

# %% [markdown]
# ### Circle Marker

# %%
import pandas as pd

data = [
    ('강남구', 37.5172, 127.0473, 564000),
    ('서초구', 37.4837, 127.0324, 444000),
    ('종로구', 37.5730, 126.9794, 153000),
    ('송파구', 37.5145, 127.1058, 671000),
    ('강서구', 37.5509, 126.8495, 588000),
    ('노원구', 37.6541, 127.0568, 514000),
]
df = pd.DataFrame(data, columns=['구', '위도', '경도', '인구'])

m3 = folium.Map(location=[37.566, 126.978], zoom_start=11)

for _, row in df.iterrows():
    folium.CircleMarker(
        location=[row['위도'], row['경도']],
        radius=row['인구'] / 20000,
        color='crimson',
        fill=True,
        fill_color='crimson',
        fill_opacity=0.5,
        tooltip=f"{row['구']}: {row['인구']:,}명"
    ).add_to(m3)

m3.save('data/map_circle.html')
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_987d12da2df3bdc9b81dc203bb6c40f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_987d12da2df3bdc9b81dc203bb6c40f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_987d12da2df3bdc9b81dc203bb6c40f9 = L.map(
#                 &quot;map_987d12da2df3bdc9b81dc203bb6c40f9&quot;,
#                 {
#                     center: [37.566, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d9df47138df91b5db3dfb61d8d57d6d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d9df47138df91b5db3dfb61d8d57d6d.addTo(map_987d12da2df3bdc9b81dc203bb6c40f9);
#
#
#             var circle_marker_4bfe01605430df2539b4e6cfd230977e = L.circleMarker(
#                 [37.5172, 127.0473],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 28.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_987d12da2df3bdc9b81dc203bb6c40f9);
#
#
#             circle_marker_4bfe01605430df2539b4e6cfd230977e.bindTooltip(
#                 `&lt;div&gt;
#                      강남구: 564,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a09672b75489a21d220adb439f396b56 = L.circleMarker(
#                 [37.4837, 127.0324],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22.2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_987d12da2df3bdc9b81dc203bb6c40f9);
#
#
#             circle_marker_a09672b75489a21d220adb439f396b56.bindTooltip(
#                 `&lt;div&gt;
#                      서초구: 444,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_b5e425edd5a685b140eee19fe72c85ba = L.circleMarker(
#                 [37.573, 126.9794],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.65, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_987d12da2df3bdc9b81dc203bb6c40f9);
#
#
#             circle_marker_b5e425edd5a685b140eee19fe72c85ba.bindTooltip(
#                 `&lt;div&gt;
#                      종로구: 153,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_260f6f4bc4e90708df9e029ce59b7b16 = L.circleMarker(
#                 [37.5145, 127.1058],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 33.55, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_987d12da2df3bdc9b81dc203bb6c40f9);
#
#
#             circle_marker_260f6f4bc4e90708df9e029ce59b7b16.bindTooltip(
#                 `&lt;div&gt;
#                      송파구: 671,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_18b7117ecc500808beeba0884d5bc754 = L.circleMarker(
#                 [37.5509, 126.8495],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArr

# %% [markdown]
# ### 지하철 2호선 혼잡도 히트맵

# %%
import folium
from folium.plugins import HeatMap

line2_stations = [
    ('강남', 37.4979, 127.0276, 200000),
    ('홍대입구', 37.5572, 126.9249, 190000),
    ('신촌', 37.5553, 126.9364, 160000),
    ('신림', 37.4846, 126.9290, 175000),
    ('구로디지털단지', 37.4854, 126.9012, 140000),
    ('잠실', 37.5133, 127.1001, 210000),
    ('왕십리', 37.5613, 127.0375, 130000),
    ('성수', 37.5445, 127.0556, 120000),
    ('서울대입구', 37.4812, 126.9528, 145000),
    ('사당', 37.4763, 126.9817, 180000),
]

m_heat = folium.Map(location=[37.530, 126.990], zoom_start=12)

# 히트맵 데이터: [위도, 경도, 가중치]
heat_data = [[s[1], s[2], s[3] / 210000] for s in line2_stations]

HeatMap(heat_data, radius=30, blur=20, max_zoom=13).add_to(m_heat)

# 역명 마커 추가
for name, lat, lon, cnt in line2_stations:
    folium.CircleMarker(
        location=[lat, lon], radius=6,
        color='darkblue', fill=True, fill_color='white',
        tooltip=f'{name}: {cnt:,}명'
    ).add_to(m_heat)

m_heat.save('data/map_subway_heat.html')
m_heat
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_389c9c8673f0e5e31d53f7387802e5ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_389c9c8673f0e5e31d53f7387802e5ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_389c9c8673f0e5e31d53f7387802e5ff = L.map(
#                 &quot;map_389c9c8673f0e5e31d53f7387802e5ff&quot;,
#                 {
#                     center: [37.53, 126.99],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13b7ec91b6ed34342bfaab258c61fbfd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13b7ec91b6ed34342bfaab258c61fbfd.addTo(map_389c9c8673f0e5e31d53f7387802e5ff);
#
#
#             var heat_map_5687c9a83626e7a380183d522749d0a6 = L.heatLayer(
#                 [[37.4979, 127.0276, 0.9523809523809523], [37.5572, 126.9249, 0.9047619047619048], [37.5553, 126.9364, 0.7619047619047619], [37.4846, 126.929, 0.8333333333333334], [37.4854, 126.9012, 0.6666666666666666], [37.5133, 127.1001, 1.0], [37.5613, 127.0375, 0.6190476190476191], [37.5445, 127.0556, 0.5714285714285714], [37.4812, 126.9528, 0.6904761904761905], [37.4763, 126.9817, 0.8571428571428571]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 13,
#   &quot;radius&quot;: 30,
#   &quot;blur&quot;: 20,
# }
#             );
#
#
#             heat_map_5687c9a83626e7a380183d522749d0a6.addTo(map_389c9c8673f0e5e31d53f7387802e5ff);
#
#
#             var circle_marker_31edc8688b7f70f097236cdc94c093f3 = L.circleMarker(
#                 [37.4979, 127.0276],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_389c9c8673f0e5e31d53f7387802e5ff);
#
#
#             circle_marker_31edc8688b7f70f097236cdc94c093f3.bindTooltip(
#                 `&lt;div&gt;
#                      강남: 200,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_24598939d12777cdc074fe8eec5924dd = L.circleMarker(
#                 [37.5572, 126.9249],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_389c9c8673f0e5e31d53f7387802e5ff);
#
#
#             circle_marker_24598939d12777cdc074fe8eec5924dd.bindTooltip(
#                 `&lt;div&gt;
#                      홍대입구: 190,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_7fa7aee358208f037b02fd227b6cb921 = L.circleMarker(
#                 [37.5553, 126.9364],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;white&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_389c9c8673f0e5e31d53f7387802e5ff);
#
#
#             circle_marker_7fa7aee358208f037b02fd227b6cb921.bindTooltip(
#                 `&lt;div&gt;
#                      신촌: 160,000명
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_aa3f4027ecc035d0187003d9cd2c65ba = L.circleMarker(
#                 [37.4846, 126.929],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkblue&quot;, &quot;dashArray&quot;: null, &quot;dash

# %% [markdown]
# ### 따릉이 대여소 위치 표시 - 자치구별 거치대수 많은 기준 대여소 1개씩

# %%
import pandas as pd
import folium

df = pd.read_excel('data/공공자전거 대여소 정보(25.12월 기준).xlsx', header=None)
df.head(10)
df_bike = df.iloc[5:, [1, 2, 4, 5, 8]]
df_bike.head()
# Out:
#              1    2          4           5   8
# 5   망원역 1번출구 앞  마포구  37.555649  126.910629  15
# 6   망원역 2번출구 앞  마포구  37.554951  126.910835  14
# 7   합정역 1번출구 앞  마포구  37.550629  126.914986  13
# 8   합정역 5번출구 앞  마포구  37.550007  126.914825   5
# 9   합정역 7번출구 앞  마포구  37.548645  126.912827  12

# %%
# 컬럼명 수정
df_bike.columns = ['대여소명', '자치구','위도', '경도', '거치대수']
df_bike.head()
# Out:
#           대여소명  자치구         위도          경도 거치대수
# 5   망원역 1번출구 앞  마포구  37.555649  126.910629   15
# 6   망원역 2번출구 앞  마포구  37.554951  126.910835   14
# 7   합정역 1번출구 앞  마포구  37.550629  126.914986   13
# 8   합정역 5번출구 앞  마포구  37.550007  126.914825    5
# 9   합정역 7번출구 앞  마포구  37.548645  126.912827   12

# %%
# 자치구별 거치대수가 가장 많은 대여소 필터
st = df_bike.loc[ df_bike.groupby('자치구')['거치대수'].sum()]
st['위도'] = st['위도'].astype(float)
st['경도'] = st['경도'].astype(float)
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 907 to 517
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소명    25 non-null     object
#  1   자치구     25 non-null     object
#  2   위도      25 non-null     float64
#  3   경도      25 non-null     float64
#  4   거치대수    9 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %%
# 지도 생성
m_bike = folium.Map(location=[37.530, 126.990], zoom_start=12)

# %%
# 마커 생성
for idx, row in st.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=row['대여소명'],
        tooltip=row['대여소명']
    ).add_to(m_bike)

m_bike.save('data/map_bike.html')
m_bike
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f05c0d7176fbd3e20cf105cbb54b214 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f05c0d7176fbd3e20cf105cbb54b214&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f05c0d7176fbd3e20cf105cbb54b214 = L.map(
#                 &quot;map_0f05c0d7176fbd3e20cf105cbb54b214&quot;,
#                 {
#                     center: [37.53, 126.99],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45f929a788a0b561e6bea78de9035fa4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45f929a788a0b561e6bea78de9035fa4.addTo(map_0f05c0d7176fbd3e20cf105cbb54b214);
#
#
#             var marker_08df17b69787f77a21fd584ed6f2ae68 = L.marker(
#                 [37.61052322, 127.05979919],
#                 {
# }
#             ).addTo(map_0f05c0d7176fbd3e20cf105cbb54b214);
#
#
#         var popup_770dee618a2b7ad72f43d737cf03255d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c30d058251eb1244ccd87d822f140995 = $(`&lt;div id=&quot;html_c30d058251eb1244ccd87d822f140995&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 석관초등학교 앞&lt;/div&gt;`)[0];
#                 popup_770dee618a2b7ad72f43d737cf03255d.setContent(html_c30d058251eb1244ccd87d822f140995);
#
#
#
#         marker_08df17b69787f77a21fd584ed6f2ae68.bindPopup(popup_770dee618a2b7ad72f43d737cf03255d)
#         ;
#
#
#
#
#             marker_08df17b69787f77a21fd584ed6f2ae68.bindTooltip(
#                 `&lt;div&gt;
#                       석관초등학교 앞
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_3efdba9fbdb6801ea08b758f256e6481 = L.marker(
#                 [37.58932877, 127.01643372],
#                 {
# }
#             ).addTo(map_0f05c0d7176fbd3e20cf105cbb54b214);
#
#
#         var popup_1870465602804597ca5a7bc0bf31019c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c7a66a99d2f04cd96d4d33b0d08912a = $(`&lt;div id=&quot;html_1c7a66a99d2f04cd96d4d33b0d08912a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 성북구청&lt;/div&gt;`)[0];
#                 popup_1870465602804597ca5a7bc0bf31019c.setContent(html_1c7a66a99d2f04cd96d4d33b0d08912a);
#
#
#
#         marker_3efdba9fbdb6801ea08b758f256e6481.bindPopup(popup_1870465602804597ca5a7bc0bf31019c)
#         ;
#
#
#
#
#             marker_3efdba9fbdb6801ea08b758f256e6481.bindTooltip(
#                 `&lt;div&gt;
#                       성북구청
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5ff738fcc4b61909c924af0f3caf9412 = L.marker(
#                 [37.57048035, 126.99663544],
#                 {
# }
#             ).addTo(map_0f05c0d7176fbd3e20cf105cbb54b214);
#
#
#         var popup_bbd68e6fbc923af572539daf62c351d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74f98d0566e1286198392939c6676ffe = $(`&lt;div id=&quot;html_74f98d0566e1286198392939c6676ffe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 종묘공영주차장 건너편&lt;/div&gt;`)[0];
#                 popup_bbd68e6fbc923af572539daf62c351d9.setContent(html_74f98d0566e1286198392939c6676ffe);
#
#
#
#         marker_5ff738fcc4b61909c924af0f3caf9412.bindPopup(popup_bbd68e6fbc923af572539daf62c351d9)
#         ;
#
#
#
#
#             marker_5ff738fcc4b61909c924af0f3caf9412.bindTooltip(
#                 `&lt;div&gt;
#                       종묘공영주차장 건너편
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f67a618059df0ef13f8d2c918efb89e7 = L.marker(
#                 [37.674366, 127.05947113],
#                 {
# }
#             ).addTo(map_0f05c0d7176fbd3e20cf105cbb54b214);
#
#
#         var popup_8fab358ad619407f7ab18f4582173711 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10588d6e80e6f681ec5b51000f20cc1b = $(`&lt;div id=&quot;html_10588d6e80e6f681ec5b51000f20cc1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; 휴플러스 수락한신아파트 101동 앞&lt;/div&gt;`)[0];
#                 popup_8fab358ad619407f7ab18f4582173711.setContent(html_10588d6e80e6f681ec5b51000f20cc1b);
#
#
#
#         marker_f67a618059df0ef13f8d2c918efb89e7.bindPopup(popup_8fab358ad619407f7ab18f4582173711)
#         ;
